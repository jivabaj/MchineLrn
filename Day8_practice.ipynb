# %% [markdown]
# <a href="https://colab.research.google.com/github/kkknewbie9/MchineLrn/blob/main/Day8_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('/content/Salary_Dataa.csv')

x = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split

x_train,x_test, y_train,y_test = train_test_split(x, y, test_size = 0.20)

print(x_train)
print(x_test)
print(y_train)
print(y_test)
# Out:
# [[ 9.5]
#  [ 6.8]
#  [10.5]
#  [ 6. ]
#  [ 5.3]
#  [ 3.2]
#  [ 4. ]
#  [ 1.5]
#  [ 4. ]
#  [ 1.1]
#  [ 3.2]
#  [ 9.6]
#  [ 3.9]
#  [ 4.5]
#  [ 2.2]
#  [ 7.9]
#  [ 8.2]
#  [ 7.1]
#  [ 5.1]
#  [ 8.7]
#  [ 2. ]
#  [ 4.1]
#  [ 3.7]
#  [10.3]]
# [[2.9]
#  [5.9]
#  [4.9]
#  [9. ]
#  [1.3]
#  [3. ]]
# [116969  91738 121872  93940  83088  64445  55794  37731  56957  39343
#   54445 112635  63218  61111  39891 101302 113812  98273  66029 109431
#   43525  57081  57189 122391]
# [ 56642  81363  67938 105582  46205  60150]

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

print(x_test)
print(x_train)
# Out:
# [[-0.92712943]
#  [ 0.13582151]
#  [-0.21849547]
#  [ 1.23420414]
#  [-1.4940366 ]
#  [-0.89169773]]
# [[ 1.41136263]
#  [ 0.45470679]
#  [ 1.76567961]
#  [ 0.17125321]
#  [-0.07676868]
#  [-0.82083433]
#  [-0.53738075]
#  [-1.4231732 ]
#  [-0.53738075]
#  [-1.56489999]
#  [-0.82083433]
#  [ 1.44679433]
#  [-0.57281245]
#  [-0.36022226]
#  [-1.17515131]
#  [ 0.84445547]
#  [ 0.95075056]
#  [ 0.56100188]
#  [-0.14763207]
#  [ 1.12790905]
#  [-1.24601471]
#  [-0.50194905]
#  [-0.64367585]
#  [ 1.69481622]]

# %%
from sklearn.tree import DecisionTreeRegressor

classifier = DecisionTreeRegressor() 

classifier.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
y_pred = classifier.predict(x_test)

# %%
print(classifier.predict(sc.transform([[3]])))

print(classifier.predict(sc.transform([[6.5]])))
# Out:
# [59445.]
# [91738.]

# %%
plt.scatter(x_train,y_train, color = 'red')
plt.plot(x_train, reg1.predict(x_train), color = 'blue')

plt.title('Decision TRee Regression')
plt.xlabel('Experience')
plt.ylabel('Salary')

plt.show()

# Sir why is my graph like this  :-(

# %%
plt.scatter(x_test,y_test, color = 'red')
plt.plot(x_train, reg1.predict(x_train), color = 'blue')

plt.title('Decision TRee Regression')
plt.xlabel('Experience')
plt.ylabel('Salary')

plt.show()

# %%
#I thought we shouldn't use grid here as we dont have exponentially increasing values, but I included it because my graph is looking like that

x_grid = np.arange(min(x_train), max(x_train))

x_grid = x_grid.reshape((len(x_grid), 1))

plt.scatter(x_train, y_train, color = 'red')
plt.plot(x_grid, reg1.predict(x_grid), color = 'blue')

plt.title('Decision TRee Regression')
plt.xlabel('Experience')
plt.ylabel('Salary')

plt.show()

# %%
x_grid = np.arange(min(x_train), max(x_train))

x_grid = x_grid.reshape((len(x_grid), 1))

plt.scatter(x_test, y_test, color = 'red')
plt.plot(x_grid, reg1.predict(x_grid), color = 'blue')

plt.title('Decision TRee Regression')
plt.xlabel('Experience')
plt.ylabel('Salary')

plt.show()
